// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
int N = 5, i = 0;
float S = 200, J = 1, P = 0;
P = S;

System.out.println("Emprestimo: parcela " + (i+1) + " eh " + P);

for(i = 1; i < N; i++){
    P = P*(1+(J/100));
    System.out.println("Emprestimo: parcela " + (i+1) + " eh " + P);
}
// Out:
// Emprestimo: parcela 1 eh 200.0
// Emprestimo: parcela 2 eh 202.0
// Emprestimo: parcela 3 eh 204.02
// Emprestimo: parcela 4 eh 206.0602
// Emprestimo: parcela 5 eh 208.12079
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Juros {
    static float calculaParcela(float S, float J, int N){
        float P = S;
        for(int i = 1; i < N; i++){
            P = P*(1+(J/100));
        }
        return P;
    }
}
// Out:
// com.twosigma.beaker.javash.bkrf4f46f95.Juros

// %%
int N = 5, i;
float S = 200, J = 1;
for(i = 1; i <= N; i++){
    System.out.println("Emprestimo: parcela " + i + " eh " + Juros.calculaParcela(S, J, i));
}
// Out:
// Emprestimo: parcela 1 eh 200.0
// Emprestimo: parcela 2 eh 202.0
// Emprestimo: parcela 3 eh 204.02
// Emprestimo: parcela 4 eh 206.0602
// Emprestimo: parcela 5 eh 208.12079
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
public class Binario {
    static String numToBin(int N){
        String B = "";
        double resultado = N;
        while(resultado > 1){
            B = (int)(resultado % 2) + B;
            resultado = Math.floor(resultado / 2);
        }
        B = 1 + B;
        return B;
    }
}
// Out:
// com.twosigma.beaker.javash.bkra54ac4c8.Binario

// %%
import java.util.Random;

Random rand = new Random();
int numero = rand.nextInt(10000);

System.out.println("O número " + numero + " em binário é " + Binario.numToBin(numero));
// Out:
// O número 5500 em binário é 1010101111100
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class Gene {
    static String DNAtoRNA (String DNA){
        String RNA = "";
        for(int i = 0; i < DNA.length(); i++){
            switch (DNA.charAt(i)) {
                case 'A' : RNA = RNA + "U"; break;
                case 'C' : RNA = RNA + "G"; break;
                case 'G' : RNA = RNA + "C"; break;
                case 'T' : RNA = RNA + "A"; break;
            }
        }
        return RNA;
    }
}
// Out:
// com.twosigma.beaker.javash.bkra54ac4c8.Gene

// %%
String DNA = "ATTACGCGCAAAC";
System.out.println("O DNA " + DNA + " convertido em RNA é " + Gene.DNAtoRNA(DNA));
// Out:
// O DNA ATTACGCGCAAAC convertido em RNA é UAAUGCGCGUUUG
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

int salarios[] = new int[50];
double media = 0;
int acimaMedia = 0;

Random rand = new Random();

for (int n = 0; n < 50; n++)
    salarios[n] = (2501 + rand.nextInt(15000-2500));

System.out.println("Salários dos funcionários:\n");
for (int n = 0; n < 50; n++){
    System.out.println("Funcionário " + (n+1) + " ganha R$" + salarios[n]);
    media = media + salarios[n];
}

media = media / 50;
System.out.println("\nA média salarial é: R$" + media);

for (int n = 0; n < 50; n++)
    if(salarios[n] > media)
        acimaMedia = acimaMedia + 1;

System.out.println("\nExistem " + acimaMedia + " funcionários que ganham salário acima da média.");
// Out:
// Salários dos funcionários:
//
// Funcionário 1 ganha R$5504
// Funcionário 2 ganha R$3839
// Funcionário 3 ganha R$12781
// Funcionário 4 ganha R$5222
// Funcionário 5 ganha R$9503
// Funcionário 6 ganha R$9611
// Funcionário 7 ganha R$12341
// Funcionário 8 ganha R$8973
// Funcionário 9 ganha R$10334
// Funcionário 10 ganha R$11613
// Funcionário 11 ganha R$6658
// Funcionário 12 ganha R$14015
// Funcionário 13 ganha R$14495
// Funcionário 14 ganha R$8610
// Funcionário 15 ganha R$10657
// Funcionário 16 ganha R$13607
// Funcionário 17 ganha R$14087
// Funcionário 18 ganha R$14906
// Funcionário 19 ganha R$8438
// Funcionário 20 ganha R$11751
// Funcionário 21 ganha R$2786
// Funcionário 22 ganha R$8520
// Funcionário 23 ganha R$7119
// Funcionário 24 ganha R$14896
// Funcionário 25 ganha R$11801
// Funcionário 26 ganha R$14884
// Funcionário 27 ganha R$12138
// Funcionário 28 ganha R$12613
// Funcionário 29 ganha R$7653
// Funcionário 30 ganha R$14075
// Funcionário 31 ganha R$3424
// Funcionário 32 ganha R$14765
// Funcionário 33 ganha R$9440
// Funcionário 34 ganha R$12947
// Funcionário 35 ganha R$9601
// Funcionário 36 ganha R$13811
// Funcionário 37 ganha R$12640
// Funcionário 38 ganha R$9610
// Funcionário 39 ganha R$10802
// Funcionário 40 ganha R$12310
// Funcionário 41 ganha R$6724
// Funcionário 42 ganha R$12890
// Funcionário 43 ganha R$3705
// Funcionário 44 ganha R$6702
// Funcionário 45 ganha R$4839
// Funcionário 46 ganha R$11727
// Funcionário 47 ganha R$7023
// Funcionário 48 ganha R$8670
// Funcionário 49 ganha R$4238
// Funcionário 50 ganha R$7909
//
// A média salarial é: R$9944.14
//
// Existem 25 funcionários que ganham salário acima da média.
// null
